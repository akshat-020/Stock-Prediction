# %% [markdown]
# <a href="https://colab.research.google.com/github/akshat-020/Stock-Prediction/blob/main/stock_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Installing the Libraries**

# %%
# !pip install yahoo_fin
# !pip install alpha_vantage
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.7/dist-packages (0.8.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.28.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.1.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.12.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: alpha_vantage in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from alpha_vantage) (2.28.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from alpha_vantage) (3.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (2.1.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (4.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->alpha_vantage) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->alpha_vantage) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->alpha_vantage) (1.25.11)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)

# %% [markdown]
# ### **Import **

# %%
import requests
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Part 1**

# %%
# Import relevant packages
import yahoo_fin.stock_info as ya
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests 
import numpy as np
# Get the 100 most traded stocks for the trading day
movers = ya.get_day_most_active()
movers.head()
# Out:
#   Symbol                                    Name  Price (Intraday)  Change  \
# 0   SNAP                               Snap Inc.              9.55   -0.08
# 1   SHOP                            Shopify Inc.             35.24    3.69
# 2    AMD            Advanced Micro Devices, Inc.             89.82    4.57
# 3   TEVA  Teva Pharmaceutical Industries Limited              9.14    2.02
# 4   AAPL                              Apple Inc.            156.79    5.19
#
#    % Change       Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# 0     -0.83  118021000.0         53857000.0   15748000000.0             NaN
# 1     11.70   79358000.0         43044000.0   45805000000.0          320.36
# 2      5.36   77041000.0        106381000.0  145554000000.0           34.41
# 3     28.37   69250000.0         11928000.0   10323000000.0             NaN
# 4      3.42   78621000.0         90907000.0          2.538T           25.49

# %%
len(movers)
# Out:
# 100

# %% [markdown]
# ### **Part 2**

# %% [markdown]
# ### **IBM Stock Data**

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data_IBM = pdr.get_data_yahoo("IBM", start="2008-01-01", end="2022-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
len(data_IBM)
# Out:
# 3608

# %%
data_IBM.head()
# Out:
#                   Open        High        Low       Close  Adj Close    Volume
# Date
# 2008-01-02  104.196938  104.196938  99.588913  100.086044  63.457779   9940661
# 2008-01-03  100.219887  100.927345  99.407265  100.286804  63.585075   7875229
# 2008-01-04   99.378586   99.378586  96.061188   96.682602  61.299889  11542192
# 2008-01-07   95.841301   96.558319  94.674950   95.650093  60.645229  13232318
# 2008-01-08   95.650093   95.965584  92.896751   93.298279  59.154102   9868382

# %% [markdown]
# ###**Technical Indicators**

# %% [markdown]
# ### **RSI-INDICATOR**

# %%
url = 'https://www.alphavantage.co/query?function=RSI&symbol=IBM&interval=daily&time_period=14&series_type=open&apikey=V23MOD5YM3ZNW9OR'
r = requests.get(url)
rsi_data = r.json()

print(rsi_data)
new_rsi= pd.DataFrame.from_dict(rsi_data['Technical Analysis: RSI'])
new1_rsi=new_rsi.transpose()
new1_rsi=new1_rsi.iloc[::-1].loc["2008-01-01":"2022-04-30", :]
print(new1_rsi)
# Out:
# {'Meta Data': {'1: Symbol': 'IBM', '2: Indicator': 'Relative Strength Index (RSI)', '3: Last Refreshed': '2022-07-27', '4: Interval': 'daily', '5: Time Period': 14, '6: Series Type': 'open', '7: Time Zone': 'US/Eastern Time'}, 'Technical Analysis: RSI': {'2022-07-27': {'RSI': '35.1503'}, '2022-07-26': {'RSI': '35.5757'}, '2022-07-25': {'RSI': '35.8255'}, '2022-07-22': {'RSI': '32.3707'}, '2022-07-21': {'RSI': '34.4729'}, '2022-07-20': {'RSI': '37.0025'}, '2022-07-19': {'RSI': '38.1764'}, '2022-07-18': {'RSI': '53.5355'}, '2022-07-15': {'RSI': '54.8016'}, '2022-07-14': {'RSI': '42.7512'}, '2022-07-13': {'RSI': '46.3177'}, '2022-07-12': {'RSI': '56.4466'}, '2022-07-11': {'RSI': '55.9084'}, '2022-07-08': {'RSI': '56.3196'}, '2022-07-07': {'RSI': '51.9862'}, '2022-07-06': {'RSI': '49.7072'}, '2022-07-05': {'RSI': '54.9502'}, '2022-07-01': {'RSI': '57.9161'}, '2022-06-30': {'RSI': '54.7925'}, '2022-06-29': {'RSI': '64.7187'}, '2022-06-28': {'RSI': '65.3448'}, '2022-06-27': {'RSI': '64.1644'}, '2022-06-24': {'RSI': '58.0061'}, '2022-06-23': {'RSI': '52.9520'}, '2022-06-22': {'RSI': '50.1388'}, '2022-06-21': {'RSI': '49.6007'}, '2022-06-17': {'RSI': '49.8254'}, '2022-06-16': {'RSI': '48.1532'}, '2022-06-15': {'RSI': '49.7370'}, '2022-06-14': {'RSI': '47.4541'}, '2022-06-13': {'RSI': '45.0926'}, '2022-06-10': {'RSI': '53.3753'}, '2022-06-09': {'RSI': '59.6142'}, '2022-06-08': {'RSI': '65.4150'}, '2022-06-07': {'RSI': '67.0883'}, '2022-06-06': {'RSI': '68.2506'}, '2022-06-03': {'RSI': '64.1187'}, '2022-06-02': {'RSI': '62.7793'}, '2022-06-01': {'RSI': '63.3759'}, '2022-05-31': {'RSI': '61.0809'}, '2022-05-27': {'RSI': '59.7916'}, '2022-05-26': {'RSI': '55.7780'}, '2022-05-25': {'RSI': '51.7757'}, '2022-05-24': {'RSI': '47.0102'}, '2022-05-23': {'RSI': '44.6365'}, '2022-05-20': {'RSI': '45.8485'}, '2022-05-19': {'RSI': '49.1663'}, '2022-05-18': {'RSI': '60.5719'}, '2022-05-17': {'RSI': '60.8030'}, '2022-05-16': {'RSI': '53.2800'}, '2022-05-13': {'RSI': '53.0756'}, '2022-05-12': {'RSI': '49.5271'}, '2022-05-11': {'RSI': '46.4631'}, '2022-05-10': {'RSI': '58.4801'}, '2022-05-09': {'RSI': '57.3030'}, '2022-05-06': {'RSI': '56.1638'}, '2022-05-05': {'RSI': '58.6016'}, '2022-05-04': {'RSI': '51.5153'}, '2022-05-03': {'RSI': '51.8136'}, '2022-05-02': {'RSI': '51.8136'}, '2022-04-29': {'RSI': '56.4285'}, '2022-04-28': {'RSI': '60.4669'}, '2022-04-27': {'RSI': '58.7621'}, '2022-04-26': {'RSI': '66.8134'}, '2022-04-25': {'RSI': '64.8555'}, '2022-04-22': {'RSI': '70.6473'}, '2022-04-21': {'RSI': '68.8475'}, '2022-04-20': {'RSI': '64.3930'}, '2022-04-19': {'RSI': '43.7774'}, '2022-04-18': {'RSI': '45.1938'}, '2022-04-14': {'RSI': '52.2243'}, '2022-04-13': {'RSI': '39.9827'}, '2022-04-12': {'RSI': '42.3729'}, '2022-04-11': {'RSI': '47.5505'}, '2022-04-08': {'RSI': '47.7630'}, '2022-04-07': {'RSI': '50.7839'}, '2022-04-06': {'RSI': '46.8258'}, '2022-04-05': {'RSI': '54.5642'}, '2022-04-04': {'RSI': '56.2747'}, '2022-04-01': {'RSI': '54.3292'}, '2022-03-31': {'RSI': '58.6069'}, '2022-03-30': {'RSI': '64.3309'}, '2022-03-29': {'RSI': '64.4668'}, '2022-03-28': {'RSI': '61.3849'}, '2022-03-25': {'RSI': '57.6988'}, '2022-03-24': {'RSI': '54.0919'}, '2022-03-23': {'RSI': '56.9841'}, '2022-03-22': {'RSI': '55.2666'}, '2022-03-21': {'RSI': '57.0913'}, '2022-03-18': {'RSI': '52.3589'}, '2022-03-17': {'RSI': '51.5004'}, '2022-03-16': {'RSI': '49.6968'}, '2022-03-15': {'RSI': '41.2423'}, '2022-03-14': {'RSI': '42.4344'}, '2022-03-11': {'RSI': '43.8736'}, '2022-03-10': {'RSI': '45.8423'}, '2022-03-09': {'RSI': '50.4995'}, '2022-03-08': {'RSI': '48.1728'}, '2022-03-07': {'RSI': '47.7397'}, '2022-03-04': {'RSI': '41.4721'}, '2022-03-03': {'RSI': '42.7604'}, '2022-03-02': {'RSI': '34.8014'}, '2022-03-01': {'RSI': '34.9538'}, '2022-02-28': {'RSI': '33.3971'}, '2022-02-25': {'RSI': '32.8783'}, '2022-02-24': {'RSI': '26.0224'}, '2022-02-23': {'RSI': '32.6359'}, '2022-02-22': {'RSI': '31.9762'}, '2022-02-18': {'RSI': '33.2181'}, '2022-02-17': {'RSI': '39.1522'}, '2022 ...
#                 RSI
# 2008-01-02  51.6058
# 2008-01-03  39.0469
# 2008-01-04  38.0455
# 2008-01-07  31.2910
# 2008-01-08  30.7916
# ...             ...
# 2022-04-25  64.8555
# 2022-04-26  66.8134
# 2022-04-27  58.7621
# 2022-04-28  60.4669
# 2022-04-29  56.4285
#
# [3608 rows x 1 columns]

# %% [markdown]
# ### **SMA- Simple moving average**

# %%
url = 'https://www.alphavantage.co/query?function=SMA&symbol=IBM&interval=daily&time_period=14&series_type=open&apikey=V23MOD5YM3ZNW9OR'
r = requests.get(url)
sma_data = r.json()

#print(sma_data)
new_sma= pd.DataFrame.from_dict(sma_data['Technical Analysis: SMA'])
new1_sma=new_sma.transpose()
new1_sma=new1_sma.iloc[::-1].loc["2008-01-01":"2022-04-30", :]
print(new1_sma)
# Out:
#                  SMA
# 2008-01-02   65.7894
# 2008-01-03   65.5930
# 2008-01-04   65.4178
# 2008-01-07   65.1170
# 2008-01-08   64.8869
# ...              ...
# 2022-04-25  128.8931
# 2022-04-26  129.5387
# 2022-04-27  130.1032
# 2022-04-28  130.6663
# 2022-04-29  131.1687
#
# [3608 rows x 1 columns]

# %% [markdown]
# ### **EMA-exponential moving average**

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=EMA&symbol=IBM&interval=daily&time_period=10&series_type=open&apikey=V23MOD5YM3ZNW9OR'
r = requests.get(url)
ema_data = r.json()

#print(ema_data)
#print(ema_data['Technical Analysis: EMA'])

new_ema= pd.DataFrame.from_dict(ema_data['Technical Analysis: EMA'])
new1_ema=new_ema.transpose()
new1_ema=new1_ema.iloc[::-1].loc["2008-01-01":"2022-04-30", :]
print(new1_ema)
# Out:
#                  EMA
# 2008-01-02   66.1968
# 2008-01-03   65.6571
# 2008-01-04   65.1649
# 2008-01-07   64.3664
# 2008-01-08   63.6795
# ...              ...
# 2022-04-25  131.5984
# 2022-04-26  132.6377
# 2022-04-27  132.9097
# 2022-04-28  133.3245
# 2022-04-29  133.3549
#
# [3608 rows x 1 columns]

# %% [markdown]
# ### **ADX-Average Directional Moving Index**

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=ADX&symbol=IBM&interval=daily&time_period=14&apikey=V23MOD5YM3ZNW9OR'
r = requests.get(url)
adx_data = r.json()

#print(adx_data)
#print(adx_data['Technical Analysis: ADX'])

new_adx= pd.DataFrame.from_dict(adx_data['Technical Analysis: ADX'])
new1_adx=new_adx.transpose()
new1_adx=new1_adx.iloc[::-1].loc["2008-01-01":"2022-04-30", :]
print(new1_adx)
# Out:
#                 ADX
# 2008-01-02  17.4261
# 2008-01-03  18.2872
# 2008-01-04  20.0685
# 2008-01-07  22.0469
# 2008-01-08  24.2552
# ...             ...
# 2022-04-25  21.9355
# 2022-04-26  23.2305
# 2022-04-27  23.7500
# 2022-04-28  24.2323
# 2022-04-29  23.5034
#
# [3608 rows x 1 columns]

# %% [markdown]
# ### **OBV-On balance volum**

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=OBV&symbol=IBM&interval=daily&apikey=V23MOD5YM3ZNW9OR'
r = requests.get(url)
obv_data = r.json()

#print(obv_data)
new_obv= pd.DataFrame.from_dict(obv_data['Technical Analysis: OBV'])
new1_obv=new_obv.transpose()
new1_obv=new1_obv.iloc[::-1].loc["2008-01-01":"2022-04-30", :]
new1_obv.index.rename('Date', inplace=True)
print(new1_obv)
# Out:
#                        OBV
# Date
# 2008-01-02   49481456.0000
# 2008-01-03   57356685.0000
# 2008-01-04   45814494.0000
# 2008-01-07   32582176.0000
# 2008-01-08   22713794.0000
# ...                    ...
# 2022-04-25  298547082.0000
# 2022-04-26  293659687.0000
# 2022-04-27  289290635.0000
# 2022-04-28  293767703.0000
# 2022-04-29  288689043.0000
#
# [3608 rows x 1 columns]

# %% [markdown]
# ### **Merging the stock data and indicators**

# %%
data_IBM = data_IBM.assign(RSI = list(new1_rsi['RSI']))
data_IBM = data_IBM.assign(EMA = list(new1_ema['EMA']))
data_IBM = data_IBM.assign(ADX = list(new1_adx['ADX']))
data_IBM = data_IBM.assign(OBV = list(new1_obv['OBV']))
data_IBM = data_IBM.assign(SMA = list(new1_sma['SMA']))

# %%
data_IBM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2008-01-02  104.196938  104.196938   99.588913  100.086044   63.457779
# 2008-01-03  100.219887  100.927345   99.407265  100.286804   63.585075
# 2008-01-04   99.378586   99.378586   96.061188   96.682602   61.299889
# 2008-01-07   95.841301   96.558319   94.674950   95.650093   60.645229
# 2008-01-08   95.650093   95.965584   92.896751   93.298279   59.154102
# ...                ...         ...         ...         ...         ...
# 2022-04-25  137.589996  139.649994  135.190002  139.100006  137.432861
# 2022-04-26  139.000000  139.869995  136.169998  136.190002  134.557739
# 2022-04-27  135.779999  137.119995  134.630005  135.059998  133.441284
# 2022-04-28  136.850006  136.990005  134.809998  135.740005  134.113144
# 2022-04-29  135.130005  135.550003  132.000000  132.210007  130.625443
#
#               Volume      RSI       EMA      ADX             OBV       SMA
# Date
# 2008-01-02   9940661  51.6058   66.1968  17.4261   49481456.0000   65.7894
# 2008-01-03   7875229  39.0469   65.6571  18.2872   57356685.0000   65.5930
# 2008-01-04  11542192  38.0455   65.1649  20.0685   45814494.0000   65.4178
# 2008-01-07  13232318  31.2910   64.3664  22.0469   32582176.0000   65.1170
# 2008-01-08   9868382  30.7916   63.6795  24.2552   22713794.0000   64.8869
# ...              ...      ...       ...      ...             ...       ...
# 2022-04-25   5748300  64.8555  131.5984  21.9355  298547082.0000  128.8931
# 2022-04-26   4956200  66.8134  132.6377  23.2305  293659687.0000  129.5387
# 2022-04-27   4369100  58.7621  132.9097  23.7500  289290635.0000  130.1032
# 2022-04-28   4474300  60.4669  133.3245  24.2323  293767703.0000  130.6663
# 2022-04-29   5078700  56.4285  133.3549  23.5034  288689043.0000  131.1687
#
# [3608 rows x 11 columns]

# %% [markdown]
# ### **Creating new Features Differential**

# %%
data_IBM = data_IBM.assign(Open_Close = list(-data_IBM['Close']+data_IBM.loc["2008-01-01":"2022-04-30", 'Open']))
data_IBM = data_IBM.assign(High_low = list(data_IBM['High']-data_IBM['Low']))

# %%
data_IBM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2008-01-02  104.196938  104.196938   99.588913  100.086044   63.457779
# 2008-01-03  100.219887  100.927345   99.407265  100.286804   63.585075
# 2008-01-04   99.378586   99.378586   96.061188   96.682602   61.299889
# 2008-01-07   95.841301   96.558319   94.674950   95.650093   60.645229
# 2008-01-08   95.650093   95.965584   92.896751   93.298279   59.154102
# ...                ...         ...         ...         ...         ...
# 2022-04-25  137.589996  139.649994  135.190002  139.100006  137.432861
# 2022-04-26  139.000000  139.869995  136.169998  136.190002  134.557739
# 2022-04-27  135.779999  137.119995  134.630005  135.059998  133.441284
# 2022-04-28  136.850006  136.990005  134.809998  135.740005  134.113144
# 2022-04-29  135.130005  135.550003  132.000000  132.210007  130.625443
#
#               Volume      RSI       EMA      ADX             OBV       SMA  \
# Date
# 2008-01-02   9940661  51.6058   66.1968  17.4261   49481456.0000   65.7894
# 2008-01-03   7875229  39.0469   65.6571  18.2872   57356685.0000   65.5930
# 2008-01-04  11542192  38.0455   65.1649  20.0685   45814494.0000   65.4178
# 2008-01-07  13232318  31.2910   64.3664  22.0469   32582176.0000   65.1170
# 2008-01-08   9868382  30.7916   63.6795  24.2552   22713794.0000   64.8869
# ...              ...      ...       ...      ...             ...       ...
# 2022-04-25   5748300  64.8555  131.5984  21.9355  298547082.0000  128.8931
# 2022-04-26   4956200  66.8134  132.6377  23.2305  293659687.0000  129.5387
# 2022-04-27   4369100  58.7621  132.9097  23.7500  289290635.0000  130.1032
# 2022-04-28   4474300  60.4669  133.3245  24.2323  293767703.0000  130.6663
# 2022-04-29   5078700  56.4285  133.3549  23.5034  288689043.0000  131.1687
#
#             Open_Close  High_low
# Date
# 2008-01-02    4.110893  4.608025
# 2008-01-03   -0.066917  1.520081
# 2008-01-04    2.695984  3.317398
# 2008-01-07    0.191208  1.883369
# 2008-01-08    2.351814  3.068832
# ...                ...       ...
# 2022-04-25   -1.510010  4.459991
# 2022-04-26    2.809998  3.699997
# 2022-04-27    0.720001  2.489990
# 2022-04-28    1.110001  2.180008
# 2022-04-29    2.919998  3.550003
#
# [3608 rows x 13 columns]

# %%
#data_IBM.at['2008-01-03']['Close']=100.286804

# %%
data_IBM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2008-01-02  104.196938  104.196938   99.588913  100.086044   63.457779
# 2008-01-03  100.219887  100.927345   99.407265  100.286804   63.585075
# 2008-01-04   99.378586   99.378586   96.061188   96.682602   61.299889
# 2008-01-07   95.841301   96.558319   94.674950   95.650093   60.645229
# 2008-01-08   95.650093   95.965584   92.896751   93.298279   59.154102
# ...                ...         ...         ...         ...         ...
# 2022-04-25  137.589996  139.649994  135.190002  139.100006  137.432861
# 2022-04-26  139.000000  139.869995  136.169998  136.190002  134.557739
# 2022-04-27  135.779999  137.119995  134.630005  135.059998  133.441284
# 2022-04-28  136.850006  136.990005  134.809998  135.740005  134.113144
# 2022-04-29  135.130005  135.550003  132.000000  132.210007  130.625443
#
#               Volume      RSI       EMA      ADX             OBV       SMA  \
# Date
# 2008-01-02   9940661  51.6058   66.1968  17.4261   49481456.0000   65.7894
# 2008-01-03   7875229  39.0469   65.6571  18.2872   57356685.0000   65.5930
# 2008-01-04  11542192  38.0455   65.1649  20.0685   45814494.0000   65.4178
# 2008-01-07  13232318  31.2910   64.3664  22.0469   32582176.0000   65.1170
# 2008-01-08   9868382  30.7916   63.6795  24.2552   22713794.0000   64.8869
# ...              ...      ...       ...      ...             ...       ...
# 2022-04-25   5748300  64.8555  131.5984  21.9355  298547082.0000  128.8931
# 2022-04-26   4956200  66.8134  132.6377  23.2305  293659687.0000  129.5387
# 2022-04-27   4369100  58.7621  132.9097  23.7500  289290635.0000  130.1032
# 2022-04-28   4474300  60.4669  133.3245  24.2323  293767703.0000  130.6663
# 2022-04-29   5078700  56.4285  133.3549  23.5034  288689043.0000  131.1687
#
#             Open_Close  High_low
# Date
# 2008-01-02    4.110893  4.608025
# 2008-01-03   -0.066917  1.520081
# 2008-01-04    2.695984  3.317398
# 2008-01-07    0.191208  1.883369
# 2008-01-08    2.351814  3.068832
# ...                ...       ...
# 2022-04-25   -1.510010  4.459991
# 2022-04-26    2.809998  3.699997
# 2022-04-27    0.720001  2.489990
# 2022-04-28    1.110001  2.180008
# 2022-04-29    2.919998  3.550003
#
# [3608 rows x 13 columns]

# %%
data_IBM['dif_open'] = data_IBM['Open'].diff(1)
data_IBM['dif_close']=data_IBM['Close'].diff(1)
data_IBM['dif_vol'] = data_IBM['Volume'].diff(1)
data_IBM['dif_high']=data_IBM['High'].diff(1)
data_IBM['dif_low'] = data_IBM['Low'].diff(1)
data_IBM['dif_adj_close']=data_IBM['Adj Close'].diff(1)
data_IBM['Real_lower_band']=data_IBM['Close'] - (0.1 * data_IBM['Close'])
data_IBM['Real_upper_band']=data_IBM['Close'] + (0.1 * data_IBM['Close'])

# %%
data_IBM=data_IBM.dropna()
data_IBM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2008-01-03  100.219887  100.927345   99.407265  100.286804   63.585075
# 2008-01-04   99.378586   99.378586   96.061188   96.682602   61.299889
# 2008-01-07   95.841301   96.558319   94.674950   95.650093   60.645229
# 2008-01-08   95.650093   95.965584   92.896751   93.298279   59.154102
# 2008-01-09   93.460800   94.789673   92.887192   93.986618   59.590530
# ...                ...         ...         ...         ...         ...
# 2022-04-25  137.589996  139.649994  135.190002  139.100006  137.432861
# 2022-04-26  139.000000  139.869995  136.169998  136.190002  134.557739
# 2022-04-27  135.779999  137.119995  134.630005  135.059998  133.441284
# 2022-04-28  136.850006  136.990005  134.809998  135.740005  134.113144
# 2022-04-29  135.130005  135.550003  132.000000  132.210007  130.625443
#
#               Volume      RSI       EMA      ADX             OBV  ...  \
# Date                                                              ...
# 2008-01-03   7875229  39.0469   65.6571  18.2872   57356685.0000  ...
# 2008-01-04  11542192  38.0455   65.1649  20.0685   45814494.0000  ...
# 2008-01-07  13232318  31.2910   64.3664  22.0469   32582176.0000  ...
# 2008-01-08   9868382  30.7916   63.6795  24.2552   22713794.0000  ...
# 2008-01-09  11424517  27.7145   62.9005  26.3078   34138310.0000  ...
# ...              ...      ...       ...      ...             ...  ...
# 2022-04-25   5748300  64.8555  131.5984  21.9355  298547082.0000  ...
# 2022-04-26   4956200  66.8134  132.6377  23.2305  293659687.0000  ...
# 2022-04-27   4369100  58.7621  132.9097  23.7500  289290635.0000  ...
# 2022-04-28   4474300  60.4669  133.3245  24.2323  293767703.0000  ...
# 2022-04-29   5078700  56.4285  133.3549  23.5034  288689043.0000  ...
#
#            Open_Close  High_low  dif_open  dif_close    dif_vol  dif_high  \
# Date
# 2008-01-03  -0.066917  1.520081 -3.977051   0.200760 -2065432.0 -3.269592
# 2008-01-04   2.695984  3.317398 -0.841301  -3.604202  3666963.0 -1.548759
# 2008-01-07   0.191208  1.883369 -3.537285  -1.032509  1690126.0 -2.820267
# 2008-01-08   2.351814  3.068832 -0.191208  -2.351814 -3363936.0 -0.592735
# 2008-01-09  -0.525818  1.902481 -2.189293   0.688339  1556135.0 -1.175911
# ...               ...       ...       ...        ...        ...       ...
# 2022-04-25  -1.510010  4.459991 -2.110001   0.850006  -760300.0 -0.790009
# 2022-04-26   2.809998  3.699997  1.410004  -2.910004  -792100.0  0.220001
# 2022-04-27   0.720001  2.489990 -3.220001  -1.130005  -587100.0 -2.750000
# 2022-04-28   1.110001  2.180008  1.070007   0.680008   105200.0 -0.129990
# 2022-04-29   2.919998  3.550003 -1.720001  -3.529999   604400.0 -1.440002
#
#              dif_low  dif_adj_close  Real_lower_band  Real_upper_band
# Date
# 2008-01-03 -0.181648       0.127296        90.258124       110.315485
# 2008-01-04 -3.346077      -2.285187        87.014342       106.350862
# 2008-01-07 -1.386238      -0.654659        86.085084       105.215102
# 2008-01-08 -1.778198      -1.491127        83.968451       102.628107
# 2008-01-09 -0.009560       0.436428        84.587956       103.385280
# ...              ...            ...              ...              ...
# 2022-04-25 -2.160004       0.839813       125.190005       153.010007
# 2022-04-26  0.979996      -2.875122       122.571002       149.809003
# 2022-04-27 -1.539993      -1.116455       121.553998       148.565997
# 2022-04-28  0.179993       0.671860       122.166005       149.314006
# 2022-04-29 -2.809998      -3.487701       118.989006       145.431007
#
# [3607 rows x 21 columns]

# %% [markdown]
# ### **Exploratory Data Analysis and Feature engineering**

# %%
data_IBM.corr()
# Out:
#                      Open      High       Low     Close  Adj Close    Volume  \
# Open             1.000000  0.999327  0.999325  0.998603   0.805251 -0.408480
# High             0.999327  1.000000  0.999107  0.999325   0.804296 -0.397690
# Low              0.999325  0.999107  1.000000  0.999319   0.806136 -0.418995
# Close            0.998603  0.999325  0.999319  1.000000   0.805146 -0.408265
# Adj Close        0.805251  0.804296  0.806136  0.805146   1.000000 -0.500989
# Volume          -0.408480 -0.397690 -0.418995 -0.408265  -0.500989  1.000000
# Open_Close       0.031571  0.005163  0.005246 -0.021294   0.006113 -0.006160
# High_low        -0.101140 -0.080179 -0.122227 -0.101037  -0.124829  0.542831
# dif_open         0.030016  0.028695  0.033353  0.031665   0.026943 -0.104331
# dif_close       -0.009851  0.008905  0.011121  0.031284   0.025903 -0.093543
# dif_vol          0.003251  0.007951 -0.001576  0.002834   0.003044  0.419181
# dif_high         0.010280  0.027237  0.024161  0.034632   0.029459 -0.041516
# dif_low          0.008847  0.017972  0.028266  0.031368   0.025899 -0.168134
# dif_adj_close   -0.009759  0.008740  0.010990  0.030808   0.029680 -0.099539
# Real_lower_band  0.998603  0.999325  0.999319  1.000000   0.805146 -0.408265
# Real_upper_band  0.998603  0.999325  0.999319  1.000000   0.805146 -0.408265
#
#                  Open_Close  High_low  dif_open  dif_close   dif_vol  \
# Open               0.031571 -0.101140  0.030016  -0.009851  0.003251
# High               0.005163 -0.080179  0.028695   0.008905  0.007951
# Low                0.005246 -0.122227  0.033353   0.011121 -0.001576
# Close             -0.021294 -0.101037  0.031665   0.031284  0.002834
# Adj Close          0.006113 -0.124829  0.026943   0.025903  0.003044
# Volume            -0.006160  0.542831 -0.104331  -0.093543  0.419181
# Open_Close         1.000000 -0.002460 -0.031039  -0.778031  0.007902
# High_low          -0.002460  1.000000 -0.112775  -0.053173  0.223943
# dif_open          -0.031039 -0.112775  1.000000   0.415887 -0.085482
# dif_close         -0.778031 -0.053173  0.415887   1.000000 -0.081442
# dif_vol            0.007902  0.223943 -0.085482  -0.081442  1.000000
# dif_high          -0.460514  0.069800  0.730684   0.756338  0.066343
# dif_low           -0.425897 -0.244645  0.763791   0.739770 -0.234769
# dif_adj_close     -0.767287 -0.053973  0.412160   0.988624 -0.088393
# Real_lower_band   -0.021294 -0.101037  0.031665   0.031284  0.002834
# Real_upper_band   -0.021294 -0.101037  0.031665   0.031284  0.002834
#
#                  dif_high   dif_low  dif_adj_close  Real_lower_band  \
# Open             0.010280  0.008847      -0.009759         0.998603
# High             0.027237  0.017972       0.008740         0.999325
# Low              0.024161  0.028266       0.010990         0.999319
# Close            0.034632  0.031368       0.030808         1.000000
# Adj Close        0.029459  0.025899       0.029680         0.805146
# Volume          -0.041516 -0.168134      -0.099539        -0.408265
# Open_Close      -0.460514 -0.425897      -0.767287        -0.021294
# High_low         0.069800 -0.244645      -0.053973        -0.101037
# dif_open         0.730684  0.763791       0.412160         0.031665
# dif_close        0.756338  0.739770       0.988624         0.031284
# dif_vol          0.066343 -0.234769      -0.088393         0.002834
# dif_high         1.000000  0.790663       0.750500         0.034632
# dif_low          0.790663  1.000000       0.734414         0.031368
# dif_adj_close    0.750500  0.734414       1.000000         0.030808
# Real_lower_band  0.034632  0.031368       0.030808         1.000000
# Real_upper_band  0.034632  0.031368       0.030808         1.000000
#
#                  Real_upper_band
# Open                    0.998603
# High                    0.999325
# Low                     0.999319
# Close                   1.000000
# Adj Close               0.805146
# Volume                 -0.408265
# Open_Close             -0.021294
# High_low               -0.101037
# dif_open                0.031665
# dif_close               0.031284
# dif_vol                 0.002834
# dif_high                0.034632
# dif_low                 0.031368
# dif_adj_close           0.030808
# Real_lower_band         1.000000
# Real_upper_band         1.000000

# %%
dataplot = sns.heatmap(data_IBM.corr(), cmap="YlGnBu",)

# %%
X=data_IBM.drop(columns= ['Close','Adj Close'])
y=data_IBM['Close']
X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### **Mutual information gain**

# %%
from sklearn.feature_selection import mutual_info_regression, SelectKBest

mi = mutual_info_regression(X_train,y_train)
mi = pd.Series(mi)
mi.index = X_train.columns
mi.sort_values(ascending=False,inplace=True)
mi
# Out:
# Real_upper_band    6.665894
# Real_lower_band    6.663017
# Low                3.501013
# High               3.500131
# Open               2.918457
# EMA                1.313136
# SMA                1.226835
# OBV                1.048070
# ADX                0.238787
# Volume             0.215500
# RSI                0.117707
# High_low           0.052698
# dif_open           0.032652
# dif_close          0.026585
# Open_Close         0.019799
# dif_adj_close      0.012232
# dif_low            0.011759
# dif_vol            0.007482
# dif_high           0.000000
# dtype: float64

# %% [markdown]
# Selecting features with contributions greater than 1.2. Dropping other features
#
# Real_upper_band
# Real_lower_band
# Low
# High
# Open
# EMA
# SMA
# OBV

# %%
X.columns
# Out:
# Index(['Open', 'High', 'Low', 'Volume', 'RSI', 'EMA', 'ADX', 'OBV', 'SMA',
#        'Open_Close', 'High_low', 'dif_open', 'dif_close', 'dif_vol',
#        'dif_high', 'dif_low', 'dif_adj_close', 'Real_lower_band',
#        'Real_upper_band'],
#       dtype='object')

# %%
X.drop(columns=['Volume', 'RSI','ADX','Open_Close', 'High_low', 'dif_open', 'dif_close', 'dif_vol','dif_high', 'dif_low', 'dif_adj_close'])
# Out:
#                   Open        High         Low       EMA             OBV  \
# Date
# 2008-01-03  100.219887  100.927345   99.407265   65.6571   57356685.0000
# 2008-01-04   99.378586   99.378586   96.061188   65.1649   45814494.0000
# 2008-01-07   95.841301   96.558319   94.674950   64.3664   32582176.0000
# 2008-01-08   95.650093   95.965584   92.896751   63.6795   22713794.0000
# 2008-01-09   93.460800   94.789673   92.887192   62.9005   34138310.0000
# ...                ...         ...         ...       ...             ...
# 2022-04-25  137.589996  139.649994  135.190002  131.5984  298547082.0000
# 2022-04-26  139.000000  139.869995  136.169998  132.6377  293659687.0000
# 2022-04-27  135.779999  137.119995  134.630005  132.9097  289290635.0000
# 2022-04-28  136.850006  136.990005  134.809998  133.3245  293767703.0000
# 2022-04-29  135.130005  135.550003  132.000000  133.3549  288689043.0000
#
#                  SMA  Real_lower_band  Real_upper_band
# Date
# 2008-01-03   65.5930        90.258124       110.315485
# 2008-01-04   65.4178        87.014342       106.350862
# 2008-01-07   65.1170        86.085084       105.215102
# 2008-01-08   64.8869        83.968451       102.628107
# 2008-01-09   64.6135        84.587956       103.385280
# ...              ...              ...              ...
# 2022-04-25  128.8931       125.190005       153.010007
# 2022-04-26  129.5387       122.571002       149.809003
# 2022-04-27  130.1032       121.553998       148.565997
# 2022-04-28  130.6663       122.166005       149.314006
# 2022-04-29  131.1687       118.989006       145.431007
#
# [3607 rows x 8 columns]

# %% [markdown]
# ### **ARIMA**
